# %%
import fitz
import urllib.request
import json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import fitz
#       2 import urllib.request
#       3 import json
#
# ModuleNotFoundError: No module named 'fitz'

# %%
doc = fitz.open('abc.pdf')

# %%
page_list = []
for page in doc:
    text = page.get_text()
    text = text.split('\n')
    text_list = []
    num = 0
    for i in text:
        text_list.append(i)
        if i == ' ' and num == 0:
            num += 1
        elif i == ' ' and num == 1:
            page_list.append(''.join(text_list))
            text_list = []
            num = 0
    print(text_list)

# %%
for page in doc:
    text = page.get_text()
    text = text.split('\n')
    text_list = []

# %%
with open('memo.txt', 'w', encoding='utf-8') as f:
    for i in page_list:
        f.write(i+'\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 with open('memo.txt', 'w', encoding='utf-8') as f:
# ----> 2     for i in page_list:
#       3         f.write(i+'\n')
#
# NameError: name 'page_list' is not defined

# %%
pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.1.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\jg999\anaconda3\lib\site-packages (from python-docx) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\jg999\anaconda3\lib\site-packages (from python-docx) (4.11.0)
# Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
# Installing collected packages: python-docx
# Successfully installed python-docx-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from docx import Document

# %%
doc = Document()
for i in page_list:
    doc.add_paragraph(i)

# 문서를 저장합니다.
doc.save('memo.docx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 doc = Document()
# ----> 2 for i in page_list:
#       3     doc.add_paragraph(i)
#       5 # 문서를 저장합니다.
#
# NameError: name 'page_list' is not defined

# %%
import re

page_list = []
for page in doc:
    text = page.get_text()
    text = text.split('\n')
    num = 0
    for i in text:
        if is_japanese(i):
            print(i)
            edit_text = input()
            if edit_text == "":
                text_list.append(i)
            else:
                text_list.append(edit_text)
        else:    
            text_list.append(i)
        if i == ' ' and num == 0:
            num += 1
        elif i == ' ' and num == 1:
            page_list.append(''.join(text_list))
            text_list = []
            num = 0

# %%
def is_japanese(text):
    pattern = r'[^\u3040-\u309F\u30A0-\u30FF\u4E00-\u9FFF\u31F0-\u31FF\uFF66-\uFF9F]'
    
    cleaned_text = re.sub(pattern, '', text)
    
    return bool(cleaned_text) and not re.search(pattern, cleaned_text)

# %%
import re

page_list = []
for page in doc:
    text = page.get_text()
    text = text.split('\n')
    
    text_list = []
    for i in text:
        if is_japanese(i):
            print(i)
            edit_text = input()
            if edit_text == "":
                text_list.append(i)
            else:
                text_list.append(edit_text)
        else:    
            text_list.append(i)
    page_list.append(text_list)
    print(text_list)
# Out:
# 킥킥……정말 음란했네, 언니♥ 전철에서 내릴 때 같은 건, 음부에서 나오는 액체로
# 水たまりができていたもの」
# 웅덩이가 생겼네
# 「うッ、うううぅ……ッ」
#
# 「うう……ッ♥  そのせいで、授業、おおッ♥  まともに受けられなかった……♥  ずっと、オマンコの中で
# 으아아♥ 그 때문에 수업, 제대로 못 받았어아아♥ 계속, 보지에서
# 、蠢いて……ッ♥」
# 꿈틀꿈틀 ...... ッ♥♥
# ['"아아아♥ 그, 그래서 ...... 다들 나를 울리려고 ...... 멋진 선배의 비참하게 우는 얼굴이 보고 싶어요♥"', '"키라한테서 딜도를 빌려서♥ 목소리가 안 나오게 입 막고 나서 ......♥ 차례대로, 보지, 강간을 오♥"', '"즐거웠어요~♥ 누나, 찔릴 때마다 벌벌 떨면서 쓰러질 것 같았어요..."', '"다들 친절하게 가슴을 잡아주고 젖꼭지를 잡아당겨주거나 젖꼭지를 잡아당겨주며 언니를 지지해줘요♪"', '"그래, 다야......♥ 나는 쓰러져 쉬지도 못하고...... 계속, 계속 오오오오오오오♥"', '킥킥……정말 음란했네, 언니♥ 전철에서 내릴 때 같은 건, 음부에서 나오는 액체로', '웅덩이가 생겼네', '"축축한 셔츠에서 야릇한 냄새를 풍기며, 축 늘어진 채로 사람들의 어깨에 기대어 끌려가는 모습......"', '"아주아주, 야했어~......♥ 언니 때문에 공부에 집중할 수 없었어♥"', '「うッ、うううぅ……ッ」', '"그래서 ...... 벌칙 게임, 어땠어?  로터로 보지를 때리면서 하루 종일 학교생활♥ 즐거웠지~~♥"', '으아아♥ 그 때문에 수업, 제대로 못 받았어아아♥ 계속, 보지에서', '꿈틀꿈틀 ...... ッ♥♥', '"스마트폰 진동이 울린다고 선생님이 말씀하셨을 때 ...... 이미 심장이 두근거려서 숨도 못 쉬겠더라고요 ......"', '"쉬는 시간에 들어갈 때마다 화장실로 끌려가 ...... 목을 조르고, 옷을 벗기고 ...... 보지가 얼마나 젖었는', '지 체크하고... ..."', '"에에~!  그렇게 즐거운 일을 하고 있었어~!  기라라도 불러줬으면 좋았을 텐데..."', '"로터를 붙이는 곳을 수업마다 바꿔서 붙였다 ...... 보지, 이제 익숙해졌지 않냐며 젖꼭지에 붙이기도 하고 ......♥"', '"여기도 개발해주겠다"며 엉덩이 구멍까지 ...... 오, 엉덩이 구멍까지 ......"', '"거짓말, 엉덩이까지! 아직 안 놀았잖아~~~ 바보 바보 바보야~! 왜 안 하냐고요~!"', '']
# 「んお゛ッふうッ♥ やめッ♥ んんん゛んッ♥ ぐるしッ、きぃらァッ♥ やめでくれえ゛ッ♥」
# 응오호호호♥ 그만해♥ 응♥ 구루し, 키라랏♥ 그만해줘♥
# "ふん......? なんか、すっごくほぐれてるよーな……いくらおねーちゃんがえちえちおまんこペットで
# ふん......? 왠지 엄청 풀린 것 같은 ...... 아무리 오 저는 키리짱의 애완동물입니다
# も、お尻がおまんこになるまで早すぎなよーな……」
# 엉덩이가 엉덩이가 되기엔 너무 이른 것 같네요 .....
# "ううっ......!    き、きぃら...... 내、오、아, 엉덩이의、구멍에...... 그......竹刀をォ......」「우우!
#
# 「んっぐうううッ♥♥   うッ、うううゥ……そ、それでは……デカケツ剣道、始め……れ、礼ッ… ...♥」 「...♥
# 앗, 윽...♥♥ 아, 아아아... 그, 그럼... 대형 엉덩이 검도, 시작... 인, 인사...♥
# ['"네가, 저항할 수 없게 만들었지 ......!  나는, 모두의 말대로 할 수 밖에 없어서', '...... 우후아♥"', '"보지에 넣어줘~라든가, 가슴을 주물러줘~라든가, 애원해봤어? 그렇게 하면 그쪽을 괴롭혀 줄지도 모르지 않겠어', '?"', '"아, 그런 거, 못하겠어, 이, 이, 히기이♥ 오시리, 그만해♥"', '"그럼 나쁜 건 언니구나 ♥ 엉덩이를 많이 괴롭혀야지 ♥ 언니도 엉덩이를 많이 괴롭혀야지~!', '~
� 아가씨, 연결됐어 ......♥"', '그만해, 제발…♥ 더 이상 다치지 않게 해줘…♥ 내 검도를… 오오오♥', '"하앗♥ 하앗♥ 세쿠스♥ 언니랑 셋이서 세쿠스♥ 하 앗, 아아아~~♥ 기분 좋아, 기분 좋아 ......♥"', '"언니 기분 좋아? 기분 좋죠? 응? 으아아아아♥"', '"으아아아아♥ 앗♥ 우아아아아♥ 이런, 이런 아아아아아아아♥ ...... ッ♥"', '"기분 좋을 때의 목소리네♥ 키라모네, 응아♥ 기분 좋네♥ 언니의 보지에, 자지러지는 것 같네♥"', '"앗, 큭 ♥ 함께 イこっ♥ ねっ？  언니, 같이, 같이, 같이, 섹스로, 앗♥꺄악, 우우~~~♥ ......♥"', '"하~~~ㅅ......♥ 하~~~ㅅ......♥ 아하하...... 이, 아차~......♥"이죠. 고소', '"무슨 일이야, 아가씨?   너한테 머리 숙이고 ...... 마치 엎드려 절하는 것 같아."', '"...... 이제 그만 용서해줘요 ...... 이런 거 참을 수 없어요 ...... 뭐든지 할게요.... ...뭐든지 다 들어줄게 ......"', '"정말~~?   그럼 안녕......(5초 정도 이야기)"', '"............!  말도 안 돼요!  그럴 리가 없잖아!"', '']
# "え～～～!   뭐든지 하겠다고 했는데 ...... 언니, 너 거짓말한 거야?"
#
# "거짓말쟁이는 벌을 받는구나. 明日も明後日もその後も……ずっとずっとずーっと、みんなでお仕置きだねぇ？」
# 거짓말쟁이는 벌을 받는구나. 내일도 모레도 그 이후도… 계속 계속 계속, 모두 함께 벌을 주는 거야, 알겠지?
# 「うッ、うゥッ……ううううぅぅぅ～～～～～～ッ……！！」
#
# 「はーい♪  それではまずぅ、デカケツ剣道からいってみよー♥  きぃらね、おねーちゃんがまけないよ
# 네♪ 그럼 우선, 대형 엉덩이 검도부터 시작해보자♥ 키라네, 언니가 지지 않을 거야.
# ーに、新技考えたんだぁ」
# 새로운 기술을 생각해봤어.
# "ふえ？ 뭐하는 거야? ...... 언니를 껴안고 있는 것뿐이라고? 여자애들끼리 하는 거잖아. 보통이지? 있잖아?"
#
# ['"え～～～!   뭐든지 하겠다고 했는데 ...... 언니, 너 거짓말한 거야?"', '"우왁......"', '거짓말쟁이는 벌을 받는구나. 내일도 모레도 그 이후도… 계속 계속 계속, 모두 함께 벌을 주는 거야, 알겠지?', '「うッ、うゥッ……ううううぅぅぅ～～～～～～ッ……！！」', '"...... 마음대로, 해라 ...... 벌을 주든 뭐든, 네 맘대로 ......"', '네♪ 그럼 우선, 대형 엉덩이 검도부터 시작해보자♥ 키라네, 언니가 지지 않을 거야.', '새로운 기술을 생각해봤어.', '"으아아아아아아아아아♥♥♥ 오, 오, 오줌싸개♥♥♥♥♥"', '"그래! 엉덩이와 보지로, 토류야! 이것이라면 분명 검도부 사람들도 이길 수 있을 거야!"', '"콧, 콧, 이런 거 ...... ♥ 응오오오오♥"', '"자, 아오네, 연습할 시간이야!   키라에게 이길 때까지 오늘은 끝나지 않을 거야♥"', '"앗, 그런......, 히잉잉♥♥♥"', '"만~응! 만-크♥ 벌써 움직임이 느려요♥ 더 반격해봐요! 그거, 만-ㅁㄴㅅㅅ! 만~♥ 만~~♥"', '"으악♥ 아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아', '아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아', '아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아아', '~~~......♥♥♥"', '##■7  아사노미야 가문의 일상④.', '"안녕하세요 ......, 와우!  오빠, 잘 자고 있는 거야?  얼굴이 너무 좋아. 괜찮아?"', '"너 ...... 도대체 무슨 일이야?    요즘 얼굴색이 안 좋아. 무슨 고민이라도 있어 ...... 응♥"', '"ふえ？ 뭐하는 거야? ...... 언니를 껴안고 있는 것뿐이라고? 여자애들끼리 하는 거잖아. 보통이지? 있잖아?"', '"음.. 그, 그렇구나. 여동생이 누나에게 애교를 부리는 건, 훗, 당연한 일이야. 그러니까 너도 나한테 잘해줘도 ', '돼. ...... 오오~♥"', '']
# "えー？  오니짱은 남자애야~~?  '응, 응, 하는 것은 아이들의 특권!  그렇죠~?
#
# "ぶぅ～～! 오빠들만 속이고 있네! 이제부터 계속 너희들 차례야! 자, 가자!"
#
# ['"えー？  오니짱은 남자애야~~?  \'응, 응, 하는 것은 아이들의 특권!  그렇죠~?', '～?"', '"훗......♥ 훗......♥ 키라...... 조금만 비켜줘"', '"...... 이란?"', '"떨어져라"', '"...... 음........ \'오니짱의 바보\'', '"자, 이리 와. ...... 뭘 부끄러워하고 있어? 안 오면 내가 갈게." 포옹. 거리가 가까워진다', '"...... 아무것도 걱정하지 마세요. 너는 ...... 너만은 내가 지켜줄게. 무슨 일이 있어도. 그러니 안심해라."', '"넌 ...... 단 하나뿐인, 가족이니까요."', '"...... 바람. 미안해, 키라. 이제 됐어."', '"ぶぅ～～! 오빠들만 속이고 있네! 이제부터 계속 너희들 차례야! 자, 가자!"', '"음.. 아, 아. 키라가 검도에 관심이 있는 것 같아서 ...... 오늘도 아침 수련이다. 내일도 모레도, 앞으로도 계속 ', '...... 으으으........"', '"얘들아, 검도 재미있어졌어♪ 언니가 손동작 하나하나 가르쳐 주니까♥"', '"...... 그래, 나는 언니야. 엄마가 부탁했어 ...... 그러니 열심히 해야지, 지켜야지 ......"', '"뭐라 중얼거리고 있어?   빨리 가자, 아가씨♪"', '"흠흠 ......!  미안하지만 오늘도 아침은 혼자 먹어줘. 하지만 ...... 저녁은 다 같이 먹자. 가족답게 다 같이 ......"', '"그것뿐이다. 그런 시간만 있으면 나는 행복하다. 그럼 ...... 다녀올게요."', '##■8  키라의 엉덩이에 모든 것을 버리게 하는 애완동물을 키운다!', '쿤니 소리', '']
# 「たの、む……目隠しを取ってくれ……それか、手錠を……おおおっ…… ♥」「♥」」아
# 재미있어... 눈 가리개를 벗겨줘... 아니면, 수갑을... 오오... ♥
# 「だめでーす♥ わんちゃんみたいにクンクンにおいを嗅いで、ペロペロごほーしできるように、特訓
# 안 돼요♥ 강아지처럼 냄새를 킁킁 맡고, 핥아서 보상을 받을 수 있도록, 특별 훈련이에요.
# しないとなんだから♪」
# 안 하면 어떻게 되니까♪
# 선생님도요, 음란한 몸으로 분위기를 어지럽히는 언니에게 매우 화가 나셨으니까, 기쁘게 생각해요
# きょーりょくしてくれたの♪」
# 협력해 줘서♪
# 「うッ、うううゥ～～～～ッ……」
#
# 「くすくす……でも、べんきょーできなくてもだいじょーぶ！ 언니는 검도를 할 수 있잖아! 있잖아?"
# 큭큭… 하지만, 공부하지 못해도 괜찮아! 언니는 검도를 할 수 있잖아! 있잖아?
# 「ぐすっ、うううっ……もういやだ……イヤだぁ……！」
# 흑흑, 윽… 더 이상 싫어… 싫어아…!
# ['큭큭♥ 괜찮아? 아직 보상은 시작에 불과하다고요~?', '"제발...... 제발 그만 좀 해주세요...... 이런, 하루 종일, 비난을 받으면, 몸이, 버티기 힘들어요......♥"', '"하하......♥ 구타에 슬러시 아줌마, 정말 대단하네......♥ 센세에게 부탁해서 정말 좋았어♥"', '"앗 ......!"', '선생님도요, 음란한 몸으로 분위기를 어지럽히는 언니에게 매우 화가 나셨으니까, 기쁘게 생각해요', '협력해 줘서♪', '"시익가카리와 함께 교시츠에서 키울 수 있게 해준대요!  어때요?  "학교로 데려가서 키운다는 건 어떤 느낌이야?"', '"너무 심했어 ...... 수업이 시작되면 의자에 묶여 ...... ♥ 선생님은 모른 척 하니까 아무도 도와줄 수 없어서.... ', '...」」라고', '"그런 상태에서 사육사들한테 온몸을 다 놀려서 ......ㅡㅡ♥ 공부, 시키지 못해서 ......ㅡㅡ♥"', '"그 때문에 시험 성적도 형편없었어♥ 오빠가 깜짝 놀랐지? 너무 당황스러웠어."', '「うッ、うううゥ～～～～ッ……」', '큭큭… 하지만, 공부하지 못해도 괜찮아! 언니는 검도를 할 수 있잖아! 있잖아?', '"켄도의 귀신, 오네짱의 부유전, 들려줘요♥"', '"검도부, 그럼, 매일매일, 검도, 시키고, 검도, 시키고........"', '"대회에서는 ...... 엉덩이에, 엉덩이에, 두꺼운 걸 넣어서 ...... 그것만으로 제대로 움직일 수 없는데........', '...... 경기 중 "...... 우우우우우우우우우우우우우우우우우우우우우우우우"', '"아, 그랬구나!  키라야 오빠가 오엔하는 앞에서 베시베시에게 얻어맞고 졌었어♥"', '"다들 실망했어~ 키라, 부끄러웠어~"', '"아, 아아아아아아아아아아아아아아아 ......"', '"와, 울어버렸어요. 요즘은 금방 울어버리네. 그렇게 힘들어?    너무 힘들어?"', '흑흑, 윽… 더 이상 싫어… 싫어아…!', '"내가 열심히 살아온 내 인생이, 내 인생이, 모두 사라지고, 빼앗겨 버린다 ......!"', '']
# 「すーっ、てするでしょ？   피부가 굉장히 예민해지는 약이에요."
# 슥, 하고 하겠죠? 피부가 굉장히 예민해지는 약이에요.
# "우엑......, 으아아아아아아악!  우아아아!  우아아아!  うわああああーーーーーーッ！！！！！」
#
# ['"이제 용서해줘요...... 보지 애완동물이라도 무엇이든 된다. 무엇이든 말만 하면 다 들어준다. 그러니 이런 삶에서 해방시', '켜줘 ......"', '"아아 ......♥ 세이코의 표정 ......♥ 드디어 진짜 고양이가 되었네♥"', '"언니는 나만 있으면 된다는 걸 알았구나 ......♥"', '"앗 ...... 아, 맞다. 그래서 ......"', '"그럼 ...... 아저씨. 저거 필요 없지?"', '"(한숨을 내쉬며) 아, 아 ......"', '"키라네, 계속 계속 생각했어. 키라네 집에 그런 건 필요 없다고. 아빠와 할머니만 있으면 된다고."', '"그래서 버릴까?  언니가 도와주면 간단할 거야. 있잖아?"', '"...... 할 수 없다"', '"뭐야?  안 들려요, 언니"', '"그것만은 안 돼요 ...... 그것만은 안 돼요 ......"', '"......', '삐삐삐삐삐삐', '"헉, 다른 일이라면 뭐든지 할게요!    뭐든 다 할게, 히이이아아아아아아아아아아아아아아아아~~~......♥"', '슥, 하고 하겠죠? 피부가 굉장히 예민해지는 약이에요.', '"내일도 모두에게 귀여움을 받을 테니, 더욱 더 야한 몸이 되어야지"', '"히힛 ......!  이, 안 돼요♥ 그 만 해 요 ♥  그만해요♥ 그만해요, 그만해요♥......♥"', '"자, 자, 자, 폭주하지 말아요~ 조심히 해야죠. 내일도 모레도 모레도 다음 주에도 다음 달에도 계속 장난감일 테니까', '요."', '"너희들만의 애완동물이 되지 않는다면, 계속 계속 계속 모두의 장난감이 될 테니까!"', '"우엑......, 으아아아아아아악!  우아아아!  우아아아!  うわああああーーーーーーッ！！！！！」', '"아하하하하하하하하하하하하하하하하하하하하하하하하하하하하하하하하하하하하하하하하하하하하하♥"', '"어째서요, 어째서요!  나는 그냥 평범하게 살고 싶을 뿐인데!  모두 함께, 가족끼리, 행복하게 살고 싶을 뿐인데!"', '']
# 「あがッ♥ かッ、母さんは、女手一つで私たちを育ててくれて、ようやくいい人と結婚して、幸せにな
# 아아♥ 어, 엄마는 혼자서 우리를 키워주셨고, 드디어 좋은 사람과 결혼해서 행복하게 되셨구나.
# れるという時に、死んでしまってぇ……ッ♥」
# 행복해질 수 있다는 때에, 돌아가시고 말았어…♥
# '이이이이이이이이이이이이이이이! きぃらッ、きぃらさまあ゛ッ♥ ゆるして、ゆるしてくださいッ、ゆる
# 이이이이이이이이이이이이이이이! 키이라ッ, 키이라님…♥ 용서해 주세요, 용서해 주세요, 용서…
# してぇぇぇ……ッ♥♥」
#
# "いり、ません"
# 필요 없어요.
#  入、ません」"
# 들어가지 않아요
# ['아아♥ 어, 엄마는 혼자서 우리를 키워주셨고, 드디어 좋은 사람과 결혼해서 행복하게 되셨구나.', '행복해질 수 있다는 때에, 돌아가시고 말았어…♥', '"남겨진 나와 남동생, 그리고 키라와 아버지와 함께 ...... ♥ 훗, 그냥 평범하게 살고 싶을 뿐인데 ♥!  행복해지고 싶', '을 뿐인데 ♥"', '"왜 이런 꼴을 당하는 거야? 다노무♥ 제발 용서해줘요♥ 평범한 가족으로 지내게 해줘요!"', '"다 , 다, 다, 다, 다, 요♥ 다, 다, 다, 버려야지♥ 다, 다, 다, 다, 다, 다, 다, 버려야지♥"', '"오니짱모오, 진세모오, 전부 다 다 털어버리고, 너의 애완동물이 되어야만 해♥"', '이이이이이이이이이이이이이이이! 키이라ッ, 키이라님…♥ 용서해 주세요, 용서해 주세요, 용서…', 'してぇぇぇ……ッ♥♥」', '"왜냐면, 그렇잖아?    난 너, 너를 정말 좋아해."', '"하아♥ 하아아♥ 아아아아아♥"', '"이 작은 엉덩이도, 큰 엉덩이도, 질퍽질퍽한 보지도, 질퍽질퍽한 보지도, 전부 다 좋아하잖아?"', '"내가 이렇게 좋아하는데 ...... 언니, 다른 사람 생각은 하지 말아요♥"', '"히익♥♥♥"', '"좋아해라♥ 너를 좋아해라♥ 말해라♥ 너 만  빼고 다 필요없다고 말해라♥"', '"살려줘, 살려줘, 살려줘 ......"', '"몸도 마음도 사람세도, 전부 전부 다 ...... 기라의 물건으로~♥♥♥♥♥♥"', '"하아♥♥♥ 하아아아아아아아아아아아아아아아아아아아', '~~~♥♥♥♥♥" 물보라가 터진다', '"휴~......♥ 휴~......♥"', '"언니, 한 번만 더 물어볼게.  "오빠, 있니?"', '필요 없어요.', '들어가지 않아요', '"들리지 않는다"', '"이...... 이리...... 이리, 아니......!"', '']
# "き、きぃら......す、すきです......あいして、ます......っ♥ だからどうかっ、おゆるしっ.... ...♥ 오요루시시, 호
# 키, 키이라... 좋아해요... 사랑해요...♥ 그러니 제발, 용서해 주세요...♥ 용서해 주세요, 호...
# "はぁーっ......♥はぁーっ......♥ (ごくん)」가
# 하아…♥ 하아…♥ (꿀꺽)
# "키라, 함께 ...... ッ♥"
#
# ['"언니의 가족은?  주인은?  여동생은 애인은 누구야?  누구일까?"', '"키라님, 입니다...... 키라님, 혼자예요......"', '"큭큭큭큭. "스스럼없이 말하지 말아요, 아가씨♪ 평소처럼 기라라고 불러요?"', '키, 키이라... 좋아해요... 사랑해요...♥ 그러니 제발, 용서해 주세요...♥ 용서해 주세요, 호...', '오오♥"', '"좋아요♥ 그럼 마지막으로 할 일이 있지요? 서로 사랑하는 둘이서, 둘이서 놀아주는 거야♥"', '하아…♥ 하아…♥ (꿀꺽)', '사고소', '"기라 ...... 사랑, 하고 있어♥ 너만을, 계속, 계속 ......♥ 그래서 ...... 내 모든 것을, 다 받아줘요! ......♥"', '입맞춤. 조개 맞추기 섹스 시작', '"후아아앙♥ 오네짱, 오네짱......♥ 스키, 스키, 스키이......♥ 대스키이......♥', '♥」"', '"음, 아아아♥ 나도 ...... 나, 나도 오오오오오오오오오오오오오오오오♥"', '"야, 핥아줘♥ 만져줘♥ 더 많이 사랑해줘♥ 애무해줘♥ 하하♥ 앗, 응컥♥ 후우엉♥"', '"쿠스...... 츄, 응, 츄～～～～♥ 응앗♥ 아~~이♥ 아~~이......♥ 모~이카이...... 응♥ 츄, 츄르르르♥ 츄르르르♥ 응', '츄! ......♥"', '"뿌핫♥ 하핫♥ 이제부터 ...... 응♥ 매일 이런 느낌이야♥ 우레시? 야, 언니♥"', '"기쁜......♥ 더, 더, 더...... 더......♥"', '"응 ♥ 매일 괴롭혀요 ♥ 매일 괴롭혀요 ♥ 매일 놀아줘요 ♥ 좋죠 ♥ 너희들끼리 만나고 있으니까 좋죠 ♥"', '"모♥ 물론♥ 응♥ 응응♥ 나는 보지 애완동물이라서♥ 키이라의, 좋아하는......♥ 쿠오오오오오오오오오오오오오오오', '오오오오오오오!', '♥」"', '"응♥ 응응♥ 좋아해♥ 더 이상 남에게 시키지 않을 거야♥ 여기는 우리들만의 보지야♥ 아아아아아아아아아아아', '아 ......♥"', '"키라, 함께 ...... ッ♥"', '']
# "ね？   키라...... 너무 무서웠어. 뭐라도 말하면 키라도 언니처럼 취급당할 것 같아서."
#
# "ふえーん. 오네짱 ......!  구스구스......"
#
# ['"응응♥ 이코♥ 언니, 언니, 언니, 언니, 챠아아아아앙......♥"', '"쿠아아아아아아아아아아~♥"', '"하아~......♥ 하아~......♥ 응~......♥ 츄~♥ 후후후~...... 귀여워요~"', '"어디에도 안 내놔요. 계속 둘이서만 있어~. 내 고양이 펫 오니짱 ♥"', '"응♥"', '##■9  아사노미야 가문의 앞으로의 일상', '"...... 왔구나"', '"언니, 괜찮아?   내가 대신 말할까?"', '"아니 ...... 괜찮아. 내가 결정한 일이니까."', '"좋은 아침입니다. 갑작스러워서 미안하지만, 너한테 집을 나가라고 한다. 나는 더 이상 ...... 너의 성폭행을 견딜 ', '수 없어."', '"매일 밤 내 침실에 들어와 입에 담기조차 끔찍한 행위를 하고 ...... 저항하면 가족이 뿔뿔이 흩어질 거라고 ', '협박한다."', '"더 이상 너 같은 놈을 가족으로 생각하고 싶지 않다. 그러니 ...... 내 앞에서 사라져줘."', '"쇼코도 있어. 키라, 열심히 했어."', '녹음이 흘러나온다. 키라의 목소리만 잘라낸 린루하의 헐떡이는 목소리.', '"ね？   키라...... 너무 무서웠어. 뭐라도 말하면 키라도 언니처럼 취급당할 것 같아서."', '"...... 미안하다. 내가 약해서 그랬어. 겁을 주었어."', '"ふえーん. 오네짱 ......!  구스구스......"', '"거짓말? 뭐가 거짓말이야? 할머니가 직접 이렇게 말했고, 키이라가 말했고, 쇼코도 여기 있다고 했잖아?"', '"...... 모든 것이 하키라의 소행이라고?  만약 그것이 사실이라면 ...... 너는 지금까지 뭘 하고 있었어?"', '"내가 키라에게 놀아나고 울부짖는 소리도 들었을 텐데 ...... 아무것도 하지 않고 귀를 막고 있었을 뿐"', '']
# ['"나는 가족을 지키려고 애를 썼는데, 너라는 놈은 ...... 한심한 동생을 둔 게 부끄럽다."', '"얘야, 이 녀석은 동생도 오빠도 아니야♥"', '"그랬구나. 이제 내 가족은 너뿐이었구나 ......♥ 응♥"', '"쯧쯧......♥ 훗♥ 앗♥ 응쯧쯧♥ 큭♥ 앗, 음......ㅡㅡ♥" 두 사람의 키스 소리', '"...... 뭘 보고 있는 거야?  빨리 나가줘요. 반자이샤아♥"', '"...... 뭘 보고 있는 거야?   빨리 나가라. 범죄자"', '경찰차 사이렌 소리.', 'END', '']

# %%
doc = Document()
for t_list in page_list:
    for t in t_list:
        doc.add_paragraph(t)
    doc.add_paragraph()

# 문서를 저장합니다.
doc.save('memo.docx')
