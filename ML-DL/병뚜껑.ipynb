# %%
import os
import cv2

def convert_to_grayscale(input_path, output_path):
    image = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)
    cv2.imwrite(output_path, image)

def rotate_image(input_path, output_path, angle):
    image = cv2.imread(input_path)
    height, width = image.shape[:2]
    center = (width / 2, height / 2)
    matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, matrix, (width, height))
    cv2.imwrite(output_path, rotated)



if not os.path.exists(output_folder):
    os.makedirs(output_folder)

for file_name in os.listdir(input_folder):
    if file_name.endswith(('.jpg', '.jpeg', '.png')):
        input_path = os.path.join(input_folder, file_name)
        output_path = os.path.join(output_folder, file_name)

        # 흑백 변환
        convert_to_grayscale(input_path, output_path)

        # 이미지 회전
        rotated_output_path = os.path.join(output_folder, 'rotated_' + file_name)
        angle = 45
        rotate_image(input_path, rotated_output_path, angle)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25888\1008373259.py in <module>
#      21     os.makedirs(output_folder)
#      22
# ---> 23 for file_name in os.listdir(input_folder):
#      24     if file_name.endswith(('.jpg', '.jpeg', '.png')):
#      25         input_path = os.path.join(input_folder, file_name)
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: 'input_folder'

# %%
import os
import cv2

def convert_to_grayscale(input_path, output_path):
    image = cv2.imread(input_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    cv2.imwrite(output_path, gray)

def rotate_image(input_path, output_path, angle):
    image = cv2.imread(input_path)
    height, width = image.shape[:2]
    center = (width / 2, height / 2)
    matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, matrix, (width, height))
    cv2.imwrite(output_path, rotated)



if not os.path.exists(output_folder):
    os.makedirs(output_folder)

for file_name in os.listdir(input_folder):
    if file_name.endswith(('.jpg', '.jpeg', '.png')):
        input_path = os.path.join(input_folder, file_name)

        # 흑백 변환
        grayscale_output_path = os.path.join(output_folder, 'grayscale_' + file_name)
        convert_to_grayscale(input_path, grayscale_output_path)

        # 이미지 회전
        rotated_output_path = os.path.join(output_folder, 'rotated_' + file_name)
        angle = 45
        rotate_image(input_path, rotated_output_path, angle)

# %%
import os
import cv2

def convert_to_grayscale(input_path, output_path):
    image = cv2.imread(input_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    cv2.imwrite(output_path, gray)

def rotate_image(input_path, output_path, angle):
    image = cv2.imread(input_path)
    height, width = image.shape[:2]
    center = (width / 2, height / 2)
    matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, matrix, (width, height))
    cv2.imwrite(output_path, rotated)


if not os.path.exists(output_folder):
    os.makedirs(output_folder)

for file_name in os.listdir(input_folder):
    if file_name.endswith(('.jpg', '.jpeg', '.png')):
        input_path = os.path.join(input_folder, file_name)

        # 흑백 변환
        grayscale_output_path = os.path.join(output_folder, file_name)
        convert_to_grayscale(input_path, grayscale_output_path)

        # 이미지 회전
        rotated_output_path = os.path.join(output_folder, 'rotated_' + file_name)
        angle = 45
        rotate_image(grayscale_output_path, rotated_output_path, angle)

# %%
import os
import cv2

def convert_to_grayscale(input_path, output_path):
    image = cv2.imread(input_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    cv2.imwrite(output_path, gray)

def rotate_image(input_path, output_path, angle):
    image = cv2.imread(input_path)
    height, width = image.shape[:2]
    center = (width / 2, height / 2)
    matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, matrix, (width, height))
    cv2.imwrite(output_path, rotated)

input_folder = 'C:/Users/jg999/Desktop/b1'  # 입력 이미지 폴더
output_folder = 'C:/Users/jg999/Desktop/c1'  # 결과 이미지 폴더

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

for file_name in os.listdir(input_folder):
    if file_name.endswith(('.jpg', '.jpeg', '.png')):
        input_path = os.path.join(input_folder, file_name)

        # 흑백 변환
        grayscale_output_path = os.path.join(output_folder, file_name)
        convert_to_grayscale(input_path, grayscale_output_path)

        # 이미지 회전
        for i in range(6):
            rotated_output_path = os.path.join(output_folder, f'rotated_{i+1}_{file_name}')
            angle = 60 * (i + 1)
            rotate_image(grayscale_output_path, rotated_output_path, angle)

# %%
import os
import cv2

def convert_to_grayscale(input_path, output_path):
    image = cv2.imread(input_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    cv2.imwrite(output_path, gray)

def rotate_image(input_path, output_path, angle):
    image = cv2.imread(input_path)
    height, width = image.shape[:2]
    center = (width / 2, height / 2)
    matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, matrix, (width, height))
    cv2.imwrite(output_path, rotated)

input_folder = 'C:/Users/jg999/Desktop/b1'  # 입력 이미지 폴더
output_folder = 'C:/Users/jg999/Desktop/c1'  # 결과 이미지 폴더

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

for file_name in os.listdir(input_folder):
    if file_name.endswith(('.jpg', '.jpeg', '.png')):
        input_path = os.path.join(input_folder, file_name)

        # 흑백 변환
        grayscale_output_path = os.path.join(output_folder, file_name)
        convert_to_grayscale(input_path, grayscale_output_path)

        # 이미지 회전
        for i in range(6):
            for j in range(12):
                angle = 30 * (j + 1)
                rotated_output_path = os.path.join(output_folder, f'{os.path.splitext(file_name)[0]}_{i+1}_{j+1}.jpg')
                rotate_image(grayscale_output_path, rotated_output_path, angle)

# %%
import os
import cv2

def convert_to_grayscale(input_path, output_path):
    image = cv2.imread(input_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    cv2.imwrite(output_path, gray)

def rotate_image(input_path, output_path, angle):
    image = cv2.imread(input_path)
    height, width = image.shape[:2]
    center = (width / 2, height / 2)
    matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, matrix, (width, height))
    cv2.imwrite(output_path, rotated)

input_folder = 'C:/Users/jg999/Desktop/b1'  # 입력 이미지 폴더
output_folder = 'C:/Users/jg999/Desktop/c/c1'  # 결과 이미지 폴더

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

for file_name in os.listdir(input_folder):
    if file_name.endswith(('.jpg', '.jpeg', '.png')):
        input_path = os.path.join(input_folder, file_name)

        # 흑백 변환
        grayscale_output_path = os.path.join(output_folder, file_name)
        convert_to_grayscale(input_path, grayscale_output_path)

        # 이미지 회전
        for i in range(6):
            angle = 60 * (j + 1)
            rotated_output_path = os.path.join(output_folder, f'{os.path.splitext(file_name)[0]}_{i*6+j+1}.jpg')
            rotate_image(grayscale_output_path, rotated_output_path, angle)

# %%
import os
import cv2

def convert_to_grayscale(input_path, output_path):
    image = cv2.imread(input_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    cv2.imwrite(output_path, gray)

def rotate_image(input_path, output_path, angle):
    image = cv2.imread(input_path)
    height, width = image.shape[:2]
    center = (width / 2, height / 2)
    matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, matrix, (width, height))
    cv2.imwrite(output_path, rotated)
    
input_folder = 'C:/Users/jg999/Desktop/iage'  # 입력 이미지 폴더
output_folder = 'C:/Users/jg999/Desktop/11'  # 결과 이미지 폴더

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

for file_name in os.listdir(input_folder):
    if file_name.endswith(('.jpg', '.jpeg', '.png')):
        input_path = os.path.join(input_folder, file_name)

        # 흑백 변환
        grayscale_output_path = os.path.join(output_folder, file_name)
        convert_to_grayscale(input_path, grayscale_output_path)

        # 이미지 회전
        for i in range(1):
            angle = 180 * (i + 1)
            rotated_output_path = os.path.join(output_folder, f'{os.path.splitext(file_name)[0]}_{i+1}.jpg')
            rotate_image(grayscale_output_path, rotated_output_path, angle)
